# %%
a=10
a=a+1
a
a+=1
a
# Out:
# 12

# %%
a=10
a-=1

# %%
name='mohsin'
if name=='mohsin':
    print("my name is mohsin")
# Out:
# my name is mohsin

# %%
name='mohsin'
increament = 0
if name=='mohsin':
    print("my name is mohsin")
    increament+=5
    print(increament)
# Out:
# my name is mohsin
# 5

# %%
name='Mohsin'
increament = 0
if name=='mohsin':
    print("my name is mohsin")
    increament+=5
    print(increament)
else:
    print("kuch bhi")
# Out:
# kuch bhi

# %%
#comparator

# %%
a=10
if a==10:
    print(a)
# Out:
# 10

# %%
num1 =69
num2 =69
if num1 !=num2:
    print("num1 ia not equal to num2")
else :
    print("both are same")
# Out:
# both are same

# %%
9==9
# Out:
# True

# %%
a=3
b=7

# %%
a<=b >=
# Out:
#   File "<ipython-input-11-ce537ef6385c>", line 1
#     a<=b >=
#             ^
# SyntaxError: invalid syntax

# %%
age = int (input("Enter your age : ")) # integer bna k same kar do type
if(age>=18):
  print("you are Adult... ")
else:
 print ("bachy hu ")

# %%
 age =int (input("Enter your age : ")) 
ifage>=18:
  print("you are Adult... ")
else:
 print ("bachy hu ")

# %%
age = int (input("Enter your age : ")) 
if age >=18:
 print("you are Adult... ")
elif age >=15:
 print("you are bacha")
else:
 print("looth hu.. ")

# %%
ticket = input("do you haveticket [Y/N]")
if ticket=='Y' :
    print("Go Ahead")

# %%
CNIC = input("you have CNIC [Y/N] : ")
if CNIC=='Y':
      list = input("you are in list..[Y/N]..")
      if list =='Y':
        print("you can caste a vote..")
else:
 print("you are not eligible ")
# Out:
# you have CNIC [Y/N] : Y
# you are in list..[Y/N]..Y
# you can caste a vote..
