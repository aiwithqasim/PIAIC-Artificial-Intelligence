# %%
peoples = [
{ 
"Person id": 0,
"first name":"John",
"last name": "Ogden",
"address": "301 Arbor Rd.",
},
{ 
"Person id": 1,
"first name":"Ann",
"last name": "Sattermyer",
"address": "PO Box 1145",
},
{ 
"Person id": 2,
"first name":"Jill",
"last name": "Somers",
"address": "3 Main St.",
},
{ 
"Person id": 2,
"first name": "David",
"last name": "Elliott",
"address": "4803 Wellesley St.",
},
]

# %%
for i in peoples:
    if (person == )
