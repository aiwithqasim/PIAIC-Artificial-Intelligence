# %% [markdown]
# # TO-DO APP

# %%
Date =input("Enter  Date [dd-mm-yyyy] = ")
Day =input("Enter Day = ")

Task_done=[]


Daily_Task =["sehri",'tilawat','rest','internship','iftari','taravi','night-circket']
print(Daily_Task)
print("\n")

while True:
    take_task = input("Enter Your Task = ").lower()
    print("\n")
    
    if take_task in Daily_Task:
        indexing_value = Daily_Task.index(take_task)
        Task_done.append(Daily_Task.pop(indexing_value))
        print("Remaining Tasks = ",Daily_Task)
        print("Your Done Tasks = ", Task_done)
        print("\n")
        
        if len(Daily_Task)==0: 
                    print("***************** Congratulation !! Your Daily Routen Tasks is completed !! *****************\n")
                    break
  
  
    else:
        print("Sorry !! But it's Not in Your Daily Tasks List Try Enter Again \n")
        
print("\n")
print("Date            =        ",Date)
print("Day             =        ",Day)
print("Your Tasks      =        ",Daily_Task)
print("Your Done Tasks =        ",Task_done)
# Out:
# Enter  Date [dd-mm-yyyy] = 28-5-2019
# Enter Day = tuesday
# ['sehri', 'tilawat', 'rest', 'internship', 'iftari', 'taravi', 'night-circket']
#
#
# Enter Your Task = sehri
#
#
# Remaining Tasks =  ['tilawat', 'rest', 'internship', 'iftari', 'taravi', 'night-circket']
# Your Done Tasks =  ['sehri']
#
#
# Enter Your Task = internship
#
#
# Remaining Tasks =  ['tilawat', 'rest', 'iftari', 'taravi', 'night-circket']
# Your Done Tasks =  ['sehri', 'internship']
#
#
# Enter Your Task = IFTARI
#
#
# Remaining Tasks =  ['tilawat', 'rest', 'taravi', 'night-circket']
# Your Done Tasks =  ['sehri', 'internship', 'iftari']
#
#
# Enter Your Task = night-circket
#
#
# Remaining Tasks =  ['tilawat', 'rest', 'taravi']
# Your Done Tasks =  ['sehri', 'internship', 'iftari', 'night-circket']
#
#
# Enter Your Task = rest
#
#
# Remaining Tasks =  ['tilawat', 'taravi']
# Your Done Tasks =  ['sehri', 'internship', 'iftari', 'night-circket', 'rest']
#
#
# Enter Your Task = tilawat
#
#
# Remaining Tasks =  ['taravi']
# Your Done Tasks =  ['sehri', 'internship', 'iftari', 'night-circket', 'rest', 'tilawat']
#
#
# Enter Your Task = taravi
#
#
# Remaining Tasks =  []
# Your Done Tasks =  ['sehri', 'internship', 'iftari', 'night-circket', 'rest', 'tilawat', 'taravi']
#
#
# ***************** Congratulation !! Your Daily Routen Tasks is completed !! *****************
#
#
#
# Date            =         28-5-2019
# Day             =         tuesday
# Your Tasks      =         []
# Your Done Tasks =         ['sehri', 'internship', 'iftari', 'night-circket', 'rest', 'tilawat', 'taravi']
