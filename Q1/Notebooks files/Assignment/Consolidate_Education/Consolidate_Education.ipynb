# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mp

# %%
Edu = pd.read_csv('Consolidated_Educational_Dataset.csv')

# %%
Edu.head()
# Out:
#   % Boys Enrolled  % Complete Primary Schools % Girls Enrolled  \
# 0          54.77%                    0.936599           45.23%
# 1          62.50%                    0.594203           37.50%
# 2          86.63%                    0.939068           13.37%
# 3          60.77%                    0.827225           39.23%
# 4          60.75%                    0.592348           39.25%
#
#    % Primary Schools with single classroom  \
# 0                                 0.034582
# 1                                 0.359903
# 2                                 0.021505
# 3                                 0.041885
# 4                                 0.346966
#
#    % Primary Schools with single teacher All Four Facilities Any One Facility  \
# 0                               0.028818              17.06%           16.20%
# 1                               0.045894              15.25%           20.21%
# 2                               0.039427               5.35%            4.55%
# ...

# %%
Edu.describe()
# Out:
#        % Complete Primary Schools  % Primary Schools with single classroom  \
# count                  576.000000                               576.000000
# mean                     0.592544                                 0.135134
# std                      0.302878                                 0.121400
# min                      0.000000                                 0.000000
# 25%                      0.340517                                 0.029740
# 50%                      0.691613                                 0.096157
# 75%                      0.846848                                 0.211669
# max                      0.994764                                 0.514768
#
#        % Primary Schools with single teacher    Area (km²)  \
# count                             576.000000    512.000000
# mean                                0.276365   6577.554688
# std                                 0.212211   7086.477548
# ...

# %%
Edu.drop("Show Sheet",axis=1,inplace=True)

# %%
Edu.drop("Table of Contents",axis=1,inplace=True)

# %%
Edu.drop("Other Factors Measure Value",axis=1,inplace=True)

# %%
Edu.drop("Color By Measure Name",axis=1,inplace=True)

# %%
Edu.drop("Drone attacks in Pakistan",axis=1,inplace=True)

# %%
Edu.drop("Number of Records",axis=1,inplace=True)

# %%
Edu.drop("Bomb Blasts Occurred",axis=1,inplace=True)

# %%
Edu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 580 entries, 0 to 579
# Data columns (total 44 columns):
# % Boys Enrolled                                                                         579 non-null object
# % Complete Primary Schools                                                              576 non-null float64
# % Girls Enrolled                                                                        579 non-null object
# % Primary Schools with single classroom                                                 576 non-null float64
# % Primary Schools with single teacher                                                   576 non-null float64
# All Four Facilities                                                                     576 non-null object
# Any One Facility                                                                        576 non-null object
# Any Three Facilities                                                                    576 non-null object
# ...

# %%
Edu.shape
# Out:
# (580, 44)

# %%
Edu.columns
# Out:
# Index(['% Boys Enrolled', '% Complete Primary Schools', '% Girls Enrolled',
#        '% Primary Schools with single classroom',
#        '% Primary Schools with single teacher', 'All Four Facilities',
#        'Any One Facility', 'Any Three Facilities', 'Any Two Facilities',
#        'Area (km²)',
#        'Boundary wall, Building condition satisfactory, Drinking water and 2 more (clusters)',
#        'Boundary wall', 'Building condition satisfactory',
#        'MeasureGroup 1 Measures', 'Color By Measure Value',
#        'Analysis Level Selector', 'Complete Primary Schools', 'Country',
#        'City', 'Drinking water', 'Education score',
#        'Educational Budget Spend of GDP', 'Electricity', 'Enrolment score',
#        'Gender parity score', 'Global Terrorism Index - Pakistan',
#        'Learning score', 'MeasureGroup 2 Measures', 'No Facility',
#        'Number of primary schools as % of total schools',
#        'Number of primary schools',
# ...

# %%
Edu.iloc[0]
# Out:
# % Boys Enrolled                                                                            54.77%
# % Complete Primary Schools                                                               0.936599
# % Girls Enrolled                                                                           45.23%
# % Primary Schools with single classroom                                                 0.0345821
# % Primary Schools with single teacher                                                   0.0288184
# All Four Facilities                                                                        17.06%
# Any One Facility                                                                           16.20%
# Any Three Facilities                                                                       24.73%
# Any Two Facilities                                                                         24.95%
# Area (km²)                                                                                    768
# ...

# %%
Edu.Country.unique()
# Out:
# array(['Pakistan'], dtype=object)

# %%
Edu.City.unique()
# Out:
# array(['Bagh', 'Bhimber', 'Hattian', 'Haveli', 'Kotli', 'Mirpur',
#        'Muzaffarabad', 'Neelum', 'Poonch', 'Sudhnutti', 'Awaran',
#        'Barkhan', 'Chaghi', 'Dera Bugti', 'Gwadar', 'Harnai',
#        'Jaffarabad', 'Jhal Magsi', 'Kachhi', 'Kalat', 'Kech', 'Kharan',
#        'Khuzdar', 'Killa Abdullah', 'Killa Saifullah', 'Kohlu', 'Lasbela',
#        'Loralai', 'Mastung', 'Musakhail', 'Nasirabad', 'Nushki',
#        'Panjgur', 'Pishin', 'Quetta', 'Sherani', 'Sibi', 'Washuk', 'Zhob',
#        'Ziarat', 'Bajaur Agency', 'FR Bannu', 'FR DI Khan', 'FR Kohat',
#        'FR Lakki Marwat', 'FR Peshawar', 'FR Tank', 'Khyber Agency',
#        'Kurram Agency', 'Mohmand Agency', 'North Waziristan Agency',
#        'Orakzai Agency', 'South Waziristan Agency', 'Astor', 'Diamir',
#        'Ghanchi', 'Ghizer', 'Gilgit', 'Hunza Nagar', 'Skardu',
#        'Islamabad', 'Abbottabad', 'Bannu', 'Batagram', 'Buner',
#        'Charsadda', 'Chitral', 'Dera Ismail Khan', 'Hangu', 'Haripur',
# ...

# %%
Edu.Province.unique()
# Out:
# array(['AJK', 'Balochistan', 'FATA', 'GB', 'ICT', 'KP', 'Punjab', 'Sindh'],
#       dtype=object)

# %%
Edu["Province"].isnull().sum()
# Out:
# 0

# %%
Province1=Edu[Edu['Province' ] == 'AJK']

# %%
Province2=Edu[Edu['Province' ] == 'Balochistan']

# %%
Province3=Edu[Edu['Province' ] == 'FATA']

# %%
Province4=Edu[Edu['Province' ] == 'GB']

# %%
Province4.dropna(axis=0)
# Out:
#     % Boys Enrolled  % Complete Primary Schools % Girls Enrolled  \
# 55           60.39%                    0.805970           39.61%
# 56           89.19%                    0.728814           10.81%
# 57           60.14%                    0.818182           39.86%
# 58           68.70%                    0.926829           31.30%
# 59           79.34%                    0.713781           20.66%
# 200          63.05%                    0.805970           36.95%
# 201          66.86%                    0.728814           33.15%
# 202          62.74%                    0.818182           37.27%
# 203          54.16%                    0.926829           45.85%
# 204          74.44%                    0.713781           25.57%
# 345          53.45%                    0.805970           46.55%
# 346          64.70%                    0.728814           35.30%
# 347          54.73%                    0.818182           45.27%
# ...

# %%
Province5=Edu[Edu['Province' ] == 'ICT']

# %%
Province6=Edu[Edu['Province' ] == 'KP']

# %%
Province6=Edu[Edu['Province' ] == 'KP']

# %%
Province7=Edu[Edu['Province' ] == 'Punjab']

# %%
Province7.dropna(axis=0)
# Out:
#     % Boys Enrolled  % Complete Primary Schools % Girls Enrolled  \
# 86           71.06%                    0.835681           28.94%
# 87           66.50%                    0.713119           33.50%
# 88           73.81%                    0.752611           26.19%
# 89           79.12%                    0.836715           20.88%
# 90           57.70%                    0.900133           42.30%
# 91           79.99%                    0.822097           20.01%
# 92           88.62%                    0.592567           11.38%
# 93           53.31%                    0.868009           46.69%
# 94           63.34%                    0.838210           36.66%
# 95           68.86%                    0.878173           31.14%
# 96           70.41%                    0.693015           29.59%
# 97           67.50%                    0.846805           32.50%
# 98           58.09%                    0.853748           41.91%
# ...

# %%
Province7.shape

Edu.Province.unique()
# Out:
# array(['AJK', 'Balochistan', 'FATA', 'GB', 'ICT', 'KP', 'Punjab', 'Sindh'],
#       dtype=object)

# %%
Province8=Edu[Edu['Province' ] == 'Sindh']

# %% [markdown]
# # 1) Population Province Wise

# %%
#pop1 = Province1.Population
Total_Popualtion = Edu.Population.sum()
Edu.Province.unique()
# Out:
# array(['AJK', 'Balochistan', 'FATA', 'GB', 'ICT', 'KP', 'Punjab', 'Sindh'],
#       dtype=object)

# %%
Total_Popualtion
# Out:
# 563452432.0

# %%
pop1 = Province1.Population.sum()
pop2 = Province2.Population.sum()
pop3 = Province3.Population.sum()
pop4 = Province4.Population.sum()
pop5 = Province5.Population.sum()
pop6 = Province6.Population.sum()
pop7 = Province7.Population.sum()
pop8 = Province8.Population.sum()

# %%
population = [pop1,pop2,pop3,pop4,pop5,pop6,pop7,pop8]
Cities = ["AJK","Balochistan","FATA","GB","ICT","KP",'Punjab','Sindh']
mp.axis("equal")
mp.pie(population,labels=Cities, shadow=False, autopct='%1.1f%%',radius=2,explode=[0.1,0.1,0.1,0.5,1.2,0.1,0.1,0.1])
mp.show()

# %% [markdown]
# # 2) Education Score Province Wise

# %%
#Edu['Education score']
pro1edu = Province1['Education score'].sum()
pro2edu = Province2['Education score'].sum()
pro3edu = Province3['Education score'].sum()
pro4edu = Province4['Education score'].sum()
pro5edu = Province5['Education score'].sum()
pro6edu = Province6['Education score'].sum()
pro7edu = Province7['Education score'].sum()
pro8edu = Province8['Education score'].sum()

# %%
population = [pro1edu,pro2edu,pro3edu,pro4edu,pro5edu,pro6edu,pro7edu,pro8edu]
Cities = ["AJK","Balochistan","FATA","GB","ICT","KP",'Punjab','Sindh']
mp.axis("equal")

mp.pie(population,labels=Cities, shadow=False, autopct='%1.1f%%',radius=2,explode=[0.1,0.1,0.1,0.1,0.5,0.1,0.1,0.1])
mp.show()

# %% [markdown]
# # 3)  Educated vs Un-Educated

# %%
pop1 = Province1.Population.sum()
pop2 = Province2.Population.sum()
pop3 = Province3.Population.sum()
pop4 = Province4.Population.sum()
pop5 = Province5.Population.sum()
pop6 = Province6.Population.sum()
pop7 = Province7.Population.sum()
pop8 = Province8.Population.sum()

# %%
pro1edu = Province1['Education score'].sum()
pro2edu = Province2['Education score'].sum()
pro3edu = Province3['Education score'].sum()
pro4edu = Province4['Education score'].sum()
pro5edu = Province5['Education score'].sum()
pro6edu = Province6['Education score'].sum()
pro7edu = Province7['Education score'].sum()
pro8edu = Province8['Education score'].sum()

# %%
uned1 = pop1-pro1edu
uned2 = pop2-pro2edu
uned3 = pop3-pro2edu
uned4 = pop4-pro2edu
uned5 = pop5-pro2edu
uned6 = pop6-pro2edu
uned7 = pop7-pro2edu
uned8 = pop8-pro2edu

# %%
mp.plot(Edu.Province.unique(),[pro1edu,pro2edu,pro3edu,pro4edu,pro5edu,pro6edu,pro7edu,pro8edu],linestyle=":",color="r",marker="o",label="Educated Person")
mp.plot(Edu.Province.unique(),[uned1,uned2,uned3,uned4,uned5,uned6,uned7,uned8],linestyle=":",color="k",marker="o",label="Un-Educated Person")
mp.grid(True)
mp.title("Educated vs Un_Educated ")
mp.xlabel("Province")
mp.ylabel("Quantity")
mp.legend()

# %% [markdown]
# # 4) Enrolled vs Educated Score

# %%
en1 = Province1["Enrolment score"].sum()
en2 = Province1["Enrolment score"].sum()
en3 = Province1["Enrolment score"].sum()
en4 = Province1["Enrolment score"].sum()
en5 = Province1["Enrolment score"].sum()
en6 = Province1["Enrolment score"].sum()
en7 = Province1["Enrolment score"].sum()
en8 = Province1["Enrolment score"].sum()

# %%
mp.plot(Edu.Province.unique(),[pro1edu,pro2edu,pro3edu,pro4edu,pro5edu,pro6edu,pro7edu,pro8edu],linestyle=":",color="r",marker="o",label="Education Score")
mp.plot(Edu.Province.unique(),[en1,en2,en3,en4,en5,en6,en7,en8],linestyle=":",color="k",marker="o",label="Enrollment Score")
mp.grid(True)
mp.title("Enrollment vs Educated Score")
mp.xlabel("Province")
mp.ylabel("Quantity")
mp.legend()

# %% [markdown]
# # 5) Year wise Education rate

# %%
Edu.Year.unique()
# Out:
# array([2013, 2014, 2015, 2016], dtype=int64)

# %%
year1 = Edu[Edu.Year == 2013]
year1EduRate = year1['Education score'].sum()

year2 = Edu[Edu.Year == 2014]
year2EduRate = year2['Education score'].sum()

year3 = Edu[Edu.Year == 2015]
year3EduRate = year3['Education score'].sum()

year4 = Edu[Edu.Year == 2016]
year4EduRate = year4['Education score'].sum()

# %%
mp.plot(["2013","2014","2015","2016"],[year1EduRate,year2EduRate,year3EduRate,year4EduRate],linestyle=":",color="g",marker="o",label="Education Score")
mp.grid(True)
mp.title("Year Wise Education Rate")
mp.xlabel("Year")
mp.ylabel("Quantity")
mp.legend()

# %% [markdown]
# # 6) Boys vs Girls Enrolled Province wise

# %%
Edu["Boys_Enrolled"] = Edu["% Boys Enrolled"].apply(lambda x : str(x))
Edu["Boys_Enrolled"] = Edu["Boys_Enrolled"].apply(lambda x : float(x.replace("%","")))
totBoysEnro = Edu["Boys_Enrolled"].sum()
Edu["Boys_Enrolled"] = Edu["Boys_Enrolled"].apply(lambda x : (x*totBoysEnro)/100).round(1)
Edu["Boys_Enrolled"].inplace=True

# %%
Edu.Province.unique()
# Out:
# array(['AJK', 'Balochistan', 'FATA', 'GB', 'ICT', 'KP', 'Punjab', 'Sindh'],
#       dtype=object)

# %%
Province1=Edu[Edu['Province'] == 'AJK']
Province2=Edu[Edu['Province'] == 'Balochistan']
Province3=Edu[Edu['Province'] == 'FATA']
Province4=Edu[Edu['Province'] == 'GB']
Province5=Edu[Edu['Province'] == 'ICT']
Province6=Edu[Edu['Province'] == 'KP']
Province7=Edu[Edu['Province'] == 'Punjab']
Province8=Edu[Edu['Province'] == 'Sindh']

# %%
boyp1 = Province1.Boys_Enrolled.sum() 
boyp2 = Province2.Boys_Enrolled.sum() 
boyp3 = Province3.Boys_Enrolled.sum() 
boyp4 = Province4.Boys_Enrolled.sum() 
boyp5 = Province5.Boys_Enrolled.sum() 
boyp6 = Province6.Boys_Enrolled.sum() 
boyp7 = Province7.Boys_Enrolled.sum() 
boyp8 = Province8.Boys_Enrolled.sum()

# %%
Edu["Girls_Enrolled"] = Edu["% Girls Enrolled"].apply(lambda x : str(x))
Edu["Girls_Enrolled"] = Edu["Girls_Enrolled"].apply(lambda x : float(x.replace("%","")))
totGirlsEnro = Edu["Girls_Enrolled"].sum()
Edu["Girls_Enrolled"] = Edu["Girls_Enrolled"].apply(lambda x : (x*totGirlsEnro)/100).round(1)
Edu["Girls_Enrolled"].inplace=True

# %%
Province1=Edu[Edu['Province'] == 'AJK']
Province2=Edu[Edu['Province'] == 'Balochistan']
Province3=Edu[Edu['Province'] == 'FATA']
Province4=Edu[Edu['Province'] == 'GB']
Province5=Edu[Edu['Province'] == 'ICT']
Province6=Edu[Edu['Province'] == 'KP']
Province7=Edu[Edu['Province'] == 'Punjab']
Province8=Edu[Edu['Province'] == 'Sindh']

# %%
girlp1 = Province1.Girls_Enrolled.sum() 
girlp2 = Province2.Girls_Enrolled.sum()
girlp3 = Province3.Girls_Enrolled.sum() 
girlp4 = Province4.Girls_Enrolled.sum()
girlp5 = Province5.Girls_Enrolled.sum() 
girlp6 = Province6.Girls_Enrolled.sum() 
girlp7 = Province7.Girls_Enrolled.sum()
girlp8 = Province8.Girls_Enrolled.sum()

# %%
mp.plot(Edu.Province.unique(),[boyp1,boyp2,boyp3,boyp4,boyp5,boyp6,boyp7,boyp8],linestyle=":",color="r",marker="o",label="Male Enrollment Score")
mp.plot(Edu.Province.unique(),[girlp1,girlp2,girlp3,girlp4,girlp5,girlp6,girlp7,girlp8],linestyle=":",color="k",marker="o",label="Female Enrollment Score")
mp.grid(True)
mp.title("Male vs Female Enrolment")
mp.xlabel("Province")
mp.ylabel("Quantity")
mp.legend()

# %% [markdown]
# # 7) Education Budget vs province

# %%
Edu["Edu_Budget"] = Edu["Educational Budget Spend of GDP"].apply(lambda x : str(x))
Edu["Edu_Budget"] = Edu["Edu_Budget"].apply(lambda x : float(x.replace("%","")))
tobudget = Edu["Edu_Budget"].sum()
Edu["Edu_Budget"] = Edu["Edu_Budget"].apply(lambda x : (x*tobudget)/100).round(1)
Edu["Edu_Budget"].inplace = True

# %%
Province1=Edu[Edu['Province'] == 'AJK']
Province2=Edu[Edu['Province'] == 'Balochistan']
Province3=Edu[Edu['Province'] == 'FATA']
Province4=Edu[Edu['Province'] == 'GB']
Province5=Edu[Edu['Province'] == 'ICT']
Province6=Edu[Edu['Province'] == 'KP']
Province7=Edu[Edu['Province'] == 'Punjab']
Province8=Edu[Edu['Province'] == 'Sindh']

# %%
eb1 = Province1.Edu_Budget.sum()
eb2 = Province2.Edu_Budget.sum()
eb3 = Province3.Edu_Budget.sum()
eb4 = Province4.Edu_Budget.sum()
eb5 = Province5.Edu_Budget.sum()
eb6 = Province6.Edu_Budget.sum()
eb7 = Province7.Edu_Budget.sum()
eb8 = Province8.Edu_Budget.sum()

# %%
mp.plot(Edu.Province.unique(),[eb1,eb2,eb3,eb4,eb5,eb6,eb7,eb8],linestyle=":",color="b",marker="o",label="Education Budget")
mp.grid(True)
mp.title("Education Budget Province Wise")
mp.xlabel("Province")
mp.ylabel("Quantity")
mp.legend()

# %% [markdown]
# # 8) Facilities vs Non Facilities provience Wise

# %%
Edu["All_Facilities"] = Edu["All Four Facilities"].apply(lambda x : str(x))
Edu["All_Facilities"] = Edu["All_Facilities"].apply(lambda x : float(x.replace("%","")))
toFourFac = Edu["All_Facilities"].sum()
Edu["All_Facilities"] = Edu["All_Facilities"].apply(lambda x : (x*toFourFac)/100).round(1)
Edu["All_Facilities"].inplace =True

# %%
Edu["No_Facilities"] = Edu["No Facility"].apply(lambda x : str(x))
Edu["No_Facilities"] = Edu["No_Facilities"].apply(lambda x : float(x.replace("%","")))
toNoFac = Edu["No_Facilities"].sum()
Edu["No_Facilities"] = Edu["No_Facilities"].apply(lambda x : (x*toNoFac)/100).round(1)
Edu["No_Facilities"].inplace = True

# %%
Province1=Edu[Edu['Province'] == 'AJK']
Province2=Edu[Edu['Province'] == 'Balochistan']
Province3=Edu[Edu['Province'] == 'FATA']
Province4=Edu[Edu['Province'] == 'GB']
Province5=Edu[Edu['Province'] == 'ICT']
Province6=Edu[Edu['Province'] == 'KP']
Province7=Edu[Edu['Province'] == 'Punjab']
Province8=Edu[Edu['Province'] == 'Sindh']

# %%
allfac1 = Province1.All_Facilities.sum()
allfac2 = Province2.All_Facilities.sum()
allfac3 = Province3.All_Facilities.sum()
allfac4 = Province4.All_Facilities.sum()
allfac5 = Province5.All_Facilities.sum()
allfac6 = Province6.All_Facilities.sum()
allfac7 = Province7.All_Facilities.sum()
allfac8 = Province8.All_Facilities.sum()

# %%
nofac1 = Province1.No_Facilities.sum()
nofac2 = Province2.No_Facilities.sum()
nofac3 = Province3.No_Facilities.sum()
nofac4 = Province4.No_Facilities.sum()
nofac5 = Province5.No_Facilities.sum()
nofac6 = Province6.No_Facilities.sum()
nofac7 = Province7.No_Facilities.sum()
nofac8 = Province8.No_Facilities.sum()

# %%
mp.plot(Edu.Province.unique(),[allfac1,allfac2,allfac3,allfac4,allfac5,allfac6,allfac7,allfac8],linestyle=":",color="r",marker="o",label="All Facilities For Students")
mp.plot(Edu.Province.unique(),[nofac1,nofac2,nofac3,nofac4,nofac5,nofac6,nofac7,nofac8],linestyle=":",color="k",marker="o",label="No Facilities For Students")
mp.grid(True)
mp.title("Facilities vs Non Facilities")
mp.xlabel("Province")
mp.ylabel("Quantity")
mp.legend()

# %% [markdown]
# # 9) Primary and Secoundry schools province wise

# %%
Province1=Edu[Edu['Province'] == 'AJK']
Province2=Edu[Edu['Province'] == 'Balochistan']
Province3=Edu[Edu['Province'] == 'FATA']
Province4=Edu[Edu['Province'] == 'GB']
Province5=Edu[Edu['Province'] == 'ICT']
Province6=Edu[Edu['Province'] == 'KP']
Province7=Edu[Edu['Province'] == 'Punjab']
Province8=Edu[Edu['Province'] == 'Sindh']

# %%
#primary schools

primr1 = Province1["Number of primary schools"].sum()
primr2 = Province2["Number of primary schools"].sum()
primr3 = Province3["Number of primary schools"].sum()
primr4 = Province4["Number of primary schools"].sum()
primr5 = Province5["Number of primary schools"].sum()
primr6 = Province6["Number of primary schools"].sum()
primr7 = Province7["Number of primary schools"].sum()
primr8 = Province8["Number of primary schools"].sum()

# %%
sec1 = Province1["Number of secondary schools"].sum()
sec2 = Province2["Number of secondary schools"].sum()
sec3 = Province3["Number of secondary schools"].sum()
sec4 = Province4["Number of secondary schools"].sum()
sec5 = Province5["Number of secondary schools"].sum()
sec6 = Province6["Number of secondary schools"].sum()
sec7 = Province7["Number of secondary schools"].sum()
sec8 = Province8["Number of secondary schools"].sum()

# %%
mp.plot(Edu.Province.unique(),[primr1,primr2,primr3,primr4,primr5,primr6,primr7,primr8],linestyle=":",color="r",marker="o",label="Primary")
mp.plot(Edu.Province.unique(),[sec1,sec2,sec3,sec4,sec5,sec6,sec7,sec8],linestyle=":",color="k",marker="o",label="Secoundry")
mp.grid(True)
mp.title("Primry and Secoundry Schools")
mp.xlabel("Province")
mp.ylabel("Quantity")
mp.legend()

# %% [markdown]
# # 10) Schools conditions satisfactory vs non satisfactory

# %%
satis1 = Province1["Building condition satisfactory"].sum()
satis2 = Province2["Building condition satisfactory"].sum()
satis3 = Province3["Building condition satisfactory"].sum()
satis4 = Province4["Building condition satisfactory"].sum()
satis5 = Province5["Building condition satisfactory"].sum()
satis6 = Province6["Building condition satisfactory"].sum()
satis7 = Province7["Building condition satisfactory"].sum()
satis8 = Province8["Building condition satisfactory"].sum()

# %%
totalSchool1 = Province1["Total number of schools"].sum()
totalSchool2 = Province2["Total number of schools"].sum()
totalSchool3 = Province3["Total number of schools"].sum()
totalSchool4 = Province4["Total number of schools"].sum()
totalSchool5 = Province5["Total number of schools"].sum()
totalSchool6 = Province6["Total number of schools"].sum()
totalSchool7 = Province7["Total number of schools"].sum()
totalSchool8 = Province8["Total number of schools"].sum()

# %%
unSatis1 = totalSchool1 - satis1
unSatis2 = totalSchool2 - satis2
unSatis3 = totalSchool3 - satis3
unSatis4 = totalSchool4 - satis4
unSatis5 = totalSchool5 - satis5
unSatis6 = totalSchool6 - satis6
unSatis7 = totalSchool7 - satis7
unSatis8 = totalSchool8 - satis8

# %%
mp.plot(Edu.Province.unique(),[satis1,satis2,satis3,satis4,satis5,satis6,satis7,satis8],linestyle=":",color="r",marker="o",label="Satisfactory Schools")
mp.plot(Edu.Province.unique(),[unSatis1,unSatis2,unSatis3,unSatis4,unSatis5,unSatis6,unSatis7,unSatis8],linestyle=":",color="k",marker="o",label="Un-Satisfactory Schools")
mp.grid(True)
mp.title("Satisfactory vs Un-Satisfactory Schools")
mp.xlabel("Province")
mp.ylabel("Quantity")
mp.legend()
